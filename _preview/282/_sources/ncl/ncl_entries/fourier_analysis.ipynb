# %% [markdown]
# # Fourier Analysis
#
# ## Overview
#
# This section covers Fourier analysis functions from NCL:
#
# - [cfftf](#cfftf)
# - [cfftb](#cfftb)

# %% [markdown]
# ## Functions

# %% [markdown]
# ### cfftf
#
# NCL's [`cfftf`](https://www.ncl.ucar.edu/Document/Functions/Built-in/cfftf.shtml) calculates an unnormalized forward complex discrete Fourier transform of a real periodic sequence

# %% [markdown]
# #### Grab and Go

# %%
import numpy as np

example_data = [
    1002,
    1017,
    1018,
    1020,
    1018,
    1027,
    1028,
    1030,
    1012,
    1012,
    982,
    1012,
    1001,
    996,
    995,
    1011,
    1027,
    1025,
    1030,
    1016,
    996,
    1006,
    1002,
    982,
]

cfftf = np.fft.fft(example_data)

print(cfftf.real)

# %% [markdown]
# ### cfftb
#
# NCL's [`cfftb`](https://www.ncl.ucar.edu/Document/Functions/Built-in/cfftb.shtml) calculates a backward complex discrete Fourier transform

# %% [markdown]
# #### Grab and Go

# %%
import numpy as np

example_data = [
    1002,
    1017,
    1018,
    1020,
    1018,
    1027,
    1028,
    1030,
    1012,
    1012,
    982,
    1012,
    1001,
    996,
    995,
    1011,
    1027,
    1025,
    1030,
    1016,
    996,
    1006,
    1002,
    982,
]

cfftb = np.fft.ifft(example_data)

print(cfftb.real)

# %% [markdown]
# Inverse Fourier transformation of the forward Fourier transform returns input data

# %%
import numpy as np

example_data = [
    1002,
    1017,
    1018,
    1020,
    1018,
    1027,
    1028,
    1030,
    1012,
    1012,
    982,
    1012,
    1001,
    996,
    995,
    1011,
    1027,
    1025,
    1030,
    1016,
    996,
    1006,
    1002,
    982,
]

cfftf = np.fft.fft(example_data)
cfftb = np.fft.ifft(cfftf)

print(cfftb.real)

# %% [markdown]
# ## Python Resources
#
# - `numpy`: [Discrete Fourier Transform](https://numpy.org/doc/stable/reference/routines.fft.html) functions
