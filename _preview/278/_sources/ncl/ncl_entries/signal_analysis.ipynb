# %% [markdown]
# # Signal Analysis

# %% [markdown]
# ## Overview
#
# This section covers signal analysis functions from NCL:
#
# - [cfftf](#cfftf)

# %% [markdown]
# ## Functions
#
# ### cfftf
# NCL's [`cfftf`](https://www.ncl.ucar.edu/Document/Functions/Built-in/cfftf.shtml) calculates an unnormalized forward complex discrete Fourier transform of a real periodic sequence

# %%
import numpy as np

example_data = [
    1002,
    1017,
    1018,
    1020,
    1018,
    1027,
    1028,
    1030,
    1012,
    1012,
    982,
    1012,
    1001,
    996,
    995,
    1011,
    1027,
    1025,
    1030,
    1016,
    996,
    1006,
    1002,
    982,
]

cfftf = np.fft.fft(example_data)

print(cfftf.real)
